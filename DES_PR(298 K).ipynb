# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.font_manager
plt.rcParams["font.family"] = "serif"

# %%
dataset = pd.read_csv('Dataset_DES.csv')
X1 = dataset.iloc [ : 5 , 1 ].values
y1 = dataset.iloc [ : 5 , 2 ].values
X2 = dataset.iloc [ 5: 12  , 1 ].values
y2 = dataset.iloc [ 5: 12 , 2 ].values
X3 = dataset.iloc [ 12: 32  , 1 ].values
y3 = dataset.iloc [ 12: 32 , 2 ].values
X4 = dataset.iloc [ 32: 44  , 1 ].values
y4 = dataset.iloc [ 32: 44 , 2 ].values

# %%
print(X1)
# Out:
# [0.093 0.193 0.293 0.393 0.492]

# %%
print(y1)
# Out:
# [0.0026 0.0064 0.0108 0.0147 0.0183]

# %%
print(X2)
# Out:
# [0.094 0.193 0.293 0.394 0.494 0.793 0.893]

# %%
print(y2)
# Out:
# [0.0038 0.0083 0.0133 0.018  0.0227 0.036  0.0411]

# %%
print(X3)
# Out:
# [0.0947 0.193  0.294  0.393  0.493  0.593  0.693  0.793  0.892  0.993
#  1.092  1.192  1.293  1.392  1.492  1.593  1.692  1.793  1.893  1.992 ]

# %%
print(y3)
# Out:
# [0.0075 0.0154 0.0231 0.0315 0.0396 0.0477 0.055  0.0633 0.0704 0.0786
#  0.0866 0.0946 0.1023 0.1097 0.1175 0.1252 0.1326 0.1402 0.1475 0.1551]

# %%
print(X4)
# Out:
# [0.094 0.193 0.293 0.394 0.492 0.992 1.093 1.193 1.493 1.793 1.892 1.993]

# %%
print(y4)
# Out:
# [0.0069 0.0138 0.021  0.028  0.0349 0.0709 0.0778 0.0847 0.1058 0.1261
#  0.1327 0.1403]

# %%
X1 = X1.reshape(len(X1),1)
y1 = y1.reshape(len(y1),1)

# %%
X2 = X2.reshape(len(X2),1)
y2 = y2.reshape(len(y2),1)

# %%
X3 = X3.reshape(len(X3),1)
y3 = y3.reshape(len(y3),1)

# %%
X4 = X4.reshape(len(X4),1)
y4 = y4.reshape(len(y4),1)

# %%
print(X1)
# Out:
# [[0.093]
#  [0.193]
#  [0.293]
#  [0.393]
#  [0.492]]

# %%
print(y1)
# Out:
# [[0.0026]
#  [0.0064]
#  [0.0108]
#  [0.0147]
#  [0.0183]]

# %%
print(X2)
# Out:
# [[0.094]
#  [0.193]
#  [0.293]
#  [0.394]
#  [0.494]
#  [0.793]
#  [0.893]]

# %%
print(y2)
# Out:
# [[0.0038]
#  [0.0083]
#  [0.0133]
#  [0.018 ]
#  [0.0227]
#  [0.036 ]
#  [0.0411]]

# %%
print(X3)
# Out:
# [[0.0947]
#  [0.193 ]
#  [0.294 ]
#  [0.393 ]
#  [0.493 ]
#  [0.593 ]
#  [0.693 ]
#  [0.793 ]
#  [0.892 ]
#  [0.993 ]
#  [1.092 ]
#  [1.192 ]
#  [1.293 ]
#  [1.392 ]
#  [1.492 ]
#  [1.593 ]
#  [1.692 ]
#  [1.793 ]
#  [1.893 ]
#  [1.992 ]]

# %%
print(y3)
# Out:
# [[0.0075]
#  [0.0154]
#  [0.0231]
#  [0.0315]
#  [0.0396]
#  [0.0477]
#  [0.055 ]
#  [0.0633]
#  [0.0704]
#  [0.0786]
#  [0.0866]
#  [0.0946]
#  [0.1023]
#  [0.1097]
#  [0.1175]
#  [0.1252]
#  [0.1326]
#  [0.1402]
#  [0.1475]
#  [0.1551]]

# %%
print(X4)
# Out:
# [[0.094]
#  [0.193]
#  [0.293]
#  [0.394]
#  [0.492]
#  [0.992]
#  [1.093]
#  [1.193]
#  [1.493]
#  [1.793]
#  [1.892]
#  [1.993]]

# %%
print(y4)
# Out:
# [[0.0069]
#  [0.0138]
#  [0.021 ]
#  [0.028 ]
#  [0.0349]
#  [0.0709]
#  [0.0778]
#  [0.0847]
#  [0.1058]
#  [0.1261]
#  [0.1327]
#  [0.1403]]

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X1, y1)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X2, y2)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X3, y3)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X4, y4)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(X1)
lin_reg_2 = LinearRegression()
lin_reg_2.fit(X_poly, y1)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree = 4)
X_poly2 = poly_reg.fit_transform(X2)
lin_reg_3 = LinearRegression()
lin_reg_3.fit(X_poly2, y2)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree = 4)
X_poly3 = poly_reg.fit_transform(X3)
lin_reg_4 = LinearRegression()
lin_reg_4.fit(X_poly3, y3)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree = 4)
X_poly4 = poly_reg.fit_transform(X4)
lin_reg_5 = LinearRegression()
lin_reg_5.fit(X_poly4, y4)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(lin_reg_2.predict(poly_reg.fit_transform([[0.10]])))
print(lin_reg_2.predict(poly_reg.fit_transform([[0.15]])))
print(lin_reg_2.predict(poly_reg.fit_transform([[0.20]])))
print(lin_reg_2.predict(poly_reg.fit_transform([[0.25]])))
print(lin_reg_2.predict(poly_reg.fit_transform([[0.30]])))
print(lin_reg_2.predict(poly_reg.fit_transform([[0.35]])))
print(lin_reg_2.predict(poly_reg.fit_transform([[0.40]])))
print(lin_reg_2.predict(poly_reg.fit_transform([[0.45]])))
print(lin_reg_2.predict(poly_reg.fit_transform([[0.50]])))
print(lin_reg_2.predict(poly_reg.fit_transform([[0.55]])))
print(lin_reg_2.predict(poly_reg.fit_transform([[0.60]])))
print(lin_reg_2.predict(poly_reg.fit_transform([[0.65]])))
print(lin_reg_2.predict(poly_reg.fit_transform([[0.70]])))
print(lin_reg_2.predict(poly_reg.fit_transform([[0.75]])))
print(lin_reg_2.predict(poly_reg.fit_transform([[0.80]])))
print(lin_reg_2.predict(poly_reg.fit_transform([[0.85]])))
print(lin_reg_2.predict(poly_reg.fit_transform([[0.90]])))
print(lin_reg_2.predict(poly_reg.fit_transform([[0.95]])))
print(lin_reg_2.predict(poly_reg.fit_transform([[1.0]])))
print(lin_reg_2.predict(poly_reg.fit_transform([[1.05]])))
print(lin_reg_2.predict(poly_reg.fit_transform([[1.10]])))
print(lin_reg_2.predict(poly_reg.fit_transform([[1.15]])))
print(lin_reg_2.predict(poly_reg.fit_transform([[1.20]])))
print(lin_reg_2.predict(poly_reg.fit_transform([[1.25]])))
print(lin_reg_2.predict(poly_reg.fit_transform([[1.30]])))
print(lin_reg_2.predict(poly_reg.fit_transform([[1.35]])))
print(lin_reg_2.predict(poly_reg.fit_transform([[1.40]])))
print(lin_reg_2.predict(poly_reg.fit_transform([[1.45]])))
print(lin_reg_2.predict(poly_reg.fit_transform([[1.50]])))
print(lin_reg_2.predict(poly_reg.fit_transform([[1.55]])))
print(lin_reg_2.predict(poly_reg.fit_transform([[1.60]])))
print(lin_reg_2.predict(poly_reg.fit_transform([[1.65]])))
print(lin_reg_2.predict(poly_reg.fit_transform([[1.70]])))
print(lin_reg_2.predict(poly_reg.fit_transform([[1.75]])))
print(lin_reg_2.predict(poly_reg.fit_transform([[1.80]])))
print(lin_reg_2.predict(poly_reg.fit_transform([[1.85]])))
print(lin_reg_2.predict(poly_reg.fit_transform([[1.90]])))
print(lin_reg_2.predict(poly_reg.fit_transform([[1.95]])))
print(lin_reg_2.predict(poly_reg.fit_transform([[2.0]])))
# Out:
# [[0.00280289]]
# [[0.00458069]]
# [[0.00670874]]
# [[0.00893572]]
# [[0.011094]]
# [[0.01309964]]
# [[0.01495241]]
# [[0.01673577]]
# [[0.01861689]]
# [[0.02084662]]
# [[0.02375952]]
# [[0.02777385]]
# [[0.03339157]]
# [[0.04119832]]
# [[0.05186346]]
# [[0.06614004]]
# [[0.08486481]]
# [[0.10895822]]
# [[0.1394244]]
# [[0.1773512]]
# [[0.22391017]]
# [[0.28035654]]
# [[0.34802925]]
# [[0.42835094]]
# [[0.52282794]]
# [[0.63305029]]
# [[0.76069172]]
# [[0.90750965]]
# [[1.07534521]]
# [[1.26612324]]
# [[1.48185224]]
# [[1.72462446]]
# [[1.99661581]]
# [[2.3000859]]
# [[2.63737806]]
# [[3.0109193]]
# [[3.42322034]]
# [[3.87687558]]
# [[4.37456315]]

# %%
print(lin_reg_3.predict(poly_reg.fit_transform([[0.10]])))
print(lin_reg_3.predict(poly_reg.fit_transform([[0.15]])))
print(lin_reg_3.predict(poly_reg.fit_transform([[0.20]])))
print(lin_reg_3.predict(poly_reg.fit_transform([[0.25]])))
print(lin_reg_3.predict(poly_reg.fit_transform([[0.30]])))
print(lin_reg_3.predict(poly_reg.fit_transform([[0.35]])))
print(lin_reg_3.predict(poly_reg.fit_transform([[0.40]])))
print(lin_reg_3.predict(poly_reg.fit_transform([[0.45]])))
print(lin_reg_3.predict(poly_reg.fit_transform([[0.50]])))
print(lin_reg_3.predict(poly_reg.fit_transform([[0.55]])))
print(lin_reg_3.predict(poly_reg.fit_transform([[0.60]])))
print(lin_reg_3.predict(poly_reg.fit_transform([[0.65]])))
print(lin_reg_3.predict(poly_reg.fit_transform([[0.70]])))
print(lin_reg_3.predict(poly_reg.fit_transform([[0.75]])))
print(lin_reg_3.predict(poly_reg.fit_transform([[0.80]])))
print(lin_reg_3.predict(poly_reg.fit_transform([[0.85]])))
print(lin_reg_3.predict(poly_reg.fit_transform([[0.90]])))
print(lin_reg_3.predict(poly_reg.fit_transform([[0.95]])))
print(lin_reg_3.predict(poly_reg.fit_transform([[1.0]])))
print(lin_reg_3.predict(poly_reg.fit_transform([[1.05]])))
print(lin_reg_3.predict(poly_reg.fit_transform([[1.10]])))
print(lin_reg_3.predict(poly_reg.fit_transform([[1.15]])))
print(lin_reg_3.predict(poly_reg.fit_transform([[1.20]])))
print(lin_reg_3.predict(poly_reg.fit_transform([[1.25]])))
print(lin_reg_3.predict(poly_reg.fit_transform([[1.30]])))
print(lin_reg_3.predict(poly_reg.fit_transform([[1.35]])))
print(lin_reg_3.predict(poly_reg.fit_transform([[1.40]])))
print(lin_reg_3.predict(poly_reg.fit_transform([[1.45]])))
print(lin_reg_3.predict(poly_reg.fit_transform([[1.50]])))
print(lin_reg_3.predict(poly_reg.fit_transform([[1.55]])))
print(lin_reg_3.predict(poly_reg.fit_transform([[1.60]])))
print(lin_reg_3.predict(poly_reg.fit_transform([[1.65]])))
print(lin_reg_3.predict(poly_reg.fit_transform([[1.70]])))
print(lin_reg_3.predict(poly_reg.fit_transform([[1.75]])))
print(lin_reg_3.predict(poly_reg.fit_transform([[1.80]])))
print(lin_reg_3.predict(poly_reg.fit_transform([[1.85]])))
print(lin_reg_3.predict(poly_reg.fit_transform([[1.90]])))
print(lin_reg_3.predict(poly_reg.fit_transform([[1.95]])))
print(lin_reg_3.predict(poly_reg.fit_transform([[2.0]])))
# Out:
# [[0.00405009]]
# [[0.00632578]]
# [[0.00869558]]
# [[0.01111485]]
# [[0.01354709]]
# [[0.01596385]]
# [[0.01834479]]
# [[0.02067766]]
# [[0.02295828]]
# [[0.02519059]]
# [[0.02738659]]
# [[0.0295664]]
# [[0.03175819]]
# [[0.03399825]]
# [[0.03633096]]
# [[0.03880878]]
# [[0.04149226]]
# [[0.04445003]]
# [[0.04775883]]
# [[0.05150348]]
# [[0.05577689]]
# [[0.06068005]]
# [[0.06632206]]
# [[0.07282009]]
# [[0.08029942]]
# [[0.08889339]]
# [[0.09874346]]
# [[0.10999916]]
# [[0.12281812]]
# [[0.13736605]]
# [[0.15381677]]
# [[0.17235216]]
# [[0.19316221]]
# [[0.216445]]
# [[0.24240668]]
# [[0.27126152]]
# [[0.30323185]]
# [[0.33854812]]
# [[0.37744883]]

# %%
print(lin_reg_4.predict(poly_reg.fit_transform([[0.10]])))
print(lin_reg_4.predict(poly_reg.fit_transform([[0.15]])))
print(lin_reg_4.predict(poly_reg.fit_transform([[0.20]])))
print(lin_reg_4.predict(poly_reg.fit_transform([[0.25]])))
print(lin_reg_4.predict(poly_reg.fit_transform([[0.30]])))
print(lin_reg_4.predict(poly_reg.fit_transform([[0.35]])))
print(lin_reg_4.predict(poly_reg.fit_transform([[0.40]])))
print(lin_reg_4.predict(poly_reg.fit_transform([[0.45]])))
print(lin_reg_4.predict(poly_reg.fit_transform([[0.50]])))
print(lin_reg_4.predict(poly_reg.fit_transform([[0.55]])))
print(lin_reg_4.predict(poly_reg.fit_transform([[0.60]])))
print(lin_reg_4.predict(poly_reg.fit_transform([[0.65]])))
print(lin_reg_4.predict(poly_reg.fit_transform([[0.70]])))
print(lin_reg_4.predict(poly_reg.fit_transform([[0.75]])))
print(lin_reg_4.predict(poly_reg.fit_transform([[0.80]])))
print(lin_reg_4.predict(poly_reg.fit_transform([[0.85]])))
print(lin_reg_4.predict(poly_reg.fit_transform([[0.90]])))
print(lin_reg_4.predict(poly_reg.fit_transform([[0.95]])))
print(lin_reg_4.predict(poly_reg.fit_transform([[1.0]])))
print(lin_reg_4.predict(poly_reg.fit_transform([[1.05]])))
print(lin_reg_4.predict(poly_reg.fit_transform([[1.10]])))
print(lin_reg_4.predict(poly_reg.fit_transform([[1.15]])))
print(lin_reg_4.predict(poly_reg.fit_transform([[1.20]])))
print(lin_reg_4.predict(poly_reg.fit_transform([[1.25]])))
print(lin_reg_4.predict(poly_reg.fit_transform([[1.30]])))
print(lin_reg_4.predict(poly_reg.fit_transform([[1.35]])))
print(lin_reg_4.predict(poly_reg.fit_transform([[1.40]])))
print(lin_reg_4.predict(poly_reg.fit_transform([[1.45]])))
print(lin_reg_4.predict(poly_reg.fit_transform([[1.50]])))
print(lin_reg_4.predict(poly_reg.fit_transform([[1.55]])))
print(lin_reg_4.predict(poly_reg.fit_transform([[1.60]])))
print(lin_reg_4.predict(poly_reg.fit_transform([[1.65]])))
print(lin_reg_4.predict(poly_reg.fit_transform([[1.70]])))
print(lin_reg_4.predict(poly_reg.fit_transform([[1.75]])))
print(lin_reg_4.predict(poly_reg.fit_transform([[1.80]])))
print(lin_reg_4.predict(poly_reg.fit_transform([[1.85]])))
print(lin_reg_4.predict(poly_reg.fit_transform([[1.90]])))
print(lin_reg_4.predict(poly_reg.fit_transform([[1.95]])))
print(lin_reg_4.predict(poly_reg.fit_transform([[2.0]])))
# Out:
# [[0.00786427]]
# [[0.01190628]]
# [[0.01593763]]
# [[0.01995896]]
# [[0.0239709]]
# [[0.02797398]]
# [[0.03196872]]
# [[0.03595555]]
# [[0.03993487]]
# [[0.04390701]]
# [[0.04787225]]
# [[0.05183083]]
# [[0.05578292]]
# [[0.05972864]]
# [[0.06366806]]
# [[0.06760119]]
# [[0.07152798]]
# [[0.07544835]]
# [[0.07936214]]
# [[0.08326914]]
# [[0.08716911]]
# [[0.09106173]]
# [[0.09494663]]
# [[0.09882339]]
# [[0.10269155]]
# [[0.10655056]]
# [[0.11039985]]
# [[0.11423879]]
# [[0.11806668]]
# [[0.12188277]]
# [[0.12568628]]
# [[0.12947634]]
# [[0.13325205]]
# [[0.13701245]]
# [[0.14075653]]
# [[0.14448321]]
# [[0.14819138]]
# [[0.15187985]]
# [[0.1555474]]

# %%
print(lin_reg_5.predict(poly_reg.fit_transform([[0.10]])))
print(lin_reg_5.predict(poly_reg.fit_transform([[0.15]])))
print(lin_reg_5.predict(poly_reg.fit_transform([[0.20]])))
print(lin_reg_5.predict(poly_reg.fit_transform([[0.25]])))
print(lin_reg_5.predict(poly_reg.fit_transform([[0.30]])))
print(lin_reg_5.predict(poly_reg.fit_transform([[0.35]])))
print(lin_reg_5.predict(poly_reg.fit_transform([[0.40]])))
print(lin_reg_5.predict(poly_reg.fit_transform([[0.45]])))
print(lin_reg_5.predict(poly_reg.fit_transform([[0.50]])))
print(lin_reg_5.predict(poly_reg.fit_transform([[0.55]])))
print(lin_reg_5.predict(poly_reg.fit_transform([[0.60]])))
print(lin_reg_5.predict(poly_reg.fit_transform([[0.65]])))
print(lin_reg_5.predict(poly_reg.fit_transform([[0.70]])))
print(lin_reg_5.predict(poly_reg.fit_transform([[0.75]])))
print(lin_reg_5.predict(poly_reg.fit_transform([[0.80]])))
print(lin_reg_5.predict(poly_reg.fit_transform([[0.85]])))
print(lin_reg_5.predict(poly_reg.fit_transform([[0.90]])))
print(lin_reg_5.predict(poly_reg.fit_transform([[0.95]])))
print(lin_reg_5.predict(poly_reg.fit_transform([[1.0]])))
print(lin_reg_5.predict(poly_reg.fit_transform([[1.05]])))
print(lin_reg_5.predict(poly_reg.fit_transform([[1.10]])))
print(lin_reg_5.predict(poly_reg.fit_transform([[1.15]])))
print(lin_reg_5.predict(poly_reg.fit_transform([[1.20]])))
print(lin_reg_5.predict(poly_reg.fit_transform([[1.25]])))
print(lin_reg_5.predict(poly_reg.fit_transform([[1.30]])))
print(lin_reg_5.predict(poly_reg.fit_transform([[1.35]])))
print(lin_reg_5.predict(poly_reg.fit_transform([[1.40]])))
print(lin_reg_5.predict(poly_reg.fit_transform([[1.45]])))
print(lin_reg_5.predict(poly_reg.fit_transform([[1.50]])))
print(lin_reg_5.predict(poly_reg.fit_transform([[1.55]])))
print(lin_reg_5.predict(poly_reg.fit_transform([[1.60]])))
print(lin_reg_5.predict(poly_reg.fit_transform([[1.65]])))
print(lin_reg_5.predict(poly_reg.fit_transform([[1.70]])))
print(lin_reg_5.predict(poly_reg.fit_transform([[1.75]])))
print(lin_reg_5.predict(poly_reg.fit_transform([[1.80]])))
print(lin_reg_5.predict(poly_reg.fit_transform([[1.85]])))
print(lin_reg_5.predict(poly_reg.fit_transform([[1.90]])))
print(lin_reg_5.predict(poly_reg.fit_transform([[1.95]])))
print(lin_reg_5.predict(poly_reg.fit_transform([[2.0]])))
# Out:
# [[0.00737188]]
# [[0.01081231]]
# [[0.01428726]]
# [[0.01779172]]
# [[0.02132095]]
# [[0.0248705]]
# [[0.02843618]]
# [[0.03201408]]
# [[0.03560059]]
# [[0.03919235]]
# [[0.04278631]]
# [[0.04637966]]
# [[0.0499699]]
# [[0.05355479]]
# [[0.05713237]]
# [[0.06070098]]
# [[0.06425922]]
# [[0.06780595]]
# [[0.07134035]]
# [[0.07486184]]
# [[0.07837014]]
# [[0.08186525]]
# [[0.08534744]]
# [[0.08881725]]
# [[0.09227551]]
# [[0.09572333]]
# [[0.0991621]]
# [[0.10259348]]
# [[0.1060194]]
# [[0.10944209]]
# [[0.11286405]]
# [[0.11628805]]
# [[0.11971715]]
# [[0.12315467]]
# [[0.12660424]]
# [[0.13006973]]
# [[0.13355532]]
# [[0.13706545]]
# [[0.14060485]]

# %%
plt.figure(figsize=(5, 4))
plt.scatter(X1, y1, color = 'red')
plt.plot(X1, lin_reg_2.predict(poly_reg.fit_transform(X1)), color = 'blue')
plt.title('DES LA:TMA-Cl (2:1) at 298K',position=(0.5, 0.9),size=12)
plt.xlabel('P(MPa)')
plt.ylabel('Solubility (mole fractions)',fontname="Times New Roman",color='black')
plt.savefig("298(1)",dpi=1500,bbox_inches = 'tight')
plt.show()

# %%
plt.figure(figsize=(5, 4))
plt.scatter(X2, y2, color = 'red')
plt.plot(X2, lin_reg_3.predict(poly_reg.fit_transform(X2)), color = 'blue')
plt.title('DES LA:TEA-Cl (2:1) at 298K',position=(0.5, 0.9),size=12)
plt.xlabel('P(MPa)')
#plt.ylabel('Solubility(mole fractions)')
plt.ylabel('Solubility (mole fractions)',fontname="Times New Roman",color='black')
plt.savefig("298(2)",dpi=1500,bbox_inches = 'tight')
plt.show()

# %%
plt.figure(figsize=(5, 4))
plt.scatter(X3, y3, color = 'red')
plt.plot(X3, lin_reg_4.predict(poly_reg.fit_transform(X3)), color = 'blue')
plt.title('DES LA:TBA-Cl (2:1) at 298K',position=(0.5, 0.9),size=12)
plt.xlabel('P(MPa)')
#plt.ylabel('Solubility(mole fractions)')
plt.ylabel('Solubility (mole fractions)',fontname="Times New Roman",color='black')
plt.savefig("298(3)",dpi=1500,bbox_inches = 'tight')
plt.show()

# %%
plt.figure(figsize=(5, 4))
plt.scatter(X4, y4, color = 'red')
plt.plot(X4, lin_reg_5.predict(poly_reg.fit_transform(X4)), color = 'blue')
plt.title('DES LA:TBA-Cl (3:1) at 298K',position=(0.5, 0.9),size=12)
plt.xlabel('P(MPa)')
#plt.ylabel('Solubility(mole fractions)')
plt.ylabel('Solubility (mole fractions)',fontname="Times New Roman",color='black')
plt.savefig("298(4)",dpi=1500,bbox_inches = 'tight')
plt.show()
